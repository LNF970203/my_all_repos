# %% [markdown]
# # Introduction to matplotlib

# %% [markdown]
# -  Matplotlib is an amazing visualization library in Python for 2D plots of arrays.
#
#
# - Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work   with the broader SciPy stack.
#
#
# -  One of the greatest benefits of visualization is that it allows us visual access to huge amounts of data in easily digestible  visuals.
#
#
# -  Matplotlib consists of several plots like line, bar, scatter, histogram etc

# %% [markdown]
# ![Matplotlob Anatomy](https://matplotlib.org/stable/_images/anatomy.png)

# %% [markdown]
# ## Axes
#
#  - Main area of the data space.
# &nbsp;
# &nbsp;
#  - Do not complicate with axis. An axes can have mupltiple axis (2 or more)
# &nbsp;
# &nbsp;
#  - given Axes object can only be in one Figure.

# %% [markdown]
# ## Axis
#  - Number line like objects.
# &nbsp;
# &nbsp;
#  - The location of the ticks is determined by a Locator object and the ticklabel strings are formatted by a Formatter. The combination of the correct Locator and Formatter gives very fine control over the tick locations and labels.

# %% [markdown]
# ## Artist
#
#  - Everthing in the plot
#  ![Artist](https://matplotlib.org/stable/_images/inheritance-50f63fede88c32059ff6460c4a9c89a5f3850a4a.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### to show the plot output
#
# ```python plt.show() ``` in IDE
#
#  for jupyter notebook ```python  % matplotlob inline ```

# %%
slcd = pd.read_csv(r"C:\Users\Sanjeth\Desktop\NIBM lectures\DATA VISUALIZATION AND INTERACTIVE DASHBOARDS USING PYTHON\Full time\Matplotlib lec 4 5 6\lec4\srilanka covid data.csv")

# %%
slcd.describe()
# Out:
#         time line    total_cases    new_cases  new_cases_smoothed  \
# count  461.000000     461.000000   461.000000          456.000000
# mean   231.000000   25275.407809   238.312364          230.790090
# std    133.223496   34311.244210   311.024985          282.873668
# min      1.000000       1.000000     0.000000            0.000000
# 25%    116.000000    1055.000000     6.000000            7.857000
# 50%    231.000000    3234.000000    35.000000           39.285500
# 75%    346.000000   46248.000000   459.000000          450.786000
# max    461.000000  109862.000000  1716.000000         1325.143000
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    400.000000   400.00000           456.000000               461.000000
# mean     159.842500     1.71750             1.448325              1180.363024
# std      211.899921     2.67218             1.904914              1602.337048
# ...

# %%
slcd.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# time line                                  int64
# total_cases                                int64
# new_cases                                  int64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# ...

# %% [markdown]
# ## Two ways to create Matplotlib plot
#
# 1. Functional Approach: Using the basic Matplotlib command, we can easily create a plot.

# %%
plt.plot(slcd['time line'], slcd['total_cases'])

# %% [markdown]
# 2. Object oriented Interface: This is the best way to create plots. The concept is  create Figure objects and call methods off it. creating a blank Figure using the .figure() method

# %%
fig = plt.figure()  # Create a figure containing a single axes.
ax = fig.add_axes([0,0,3,1]) # left. bottom, width. height
ax.plot(slcd['time line'], slcd['total_cases'])

# %%
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(slcd['time line'], slcd['total_cases'], label='total cases')  # Plot some data on the axes.
ax.set_xlabel('Time line')
ax.set_ylabel('Total cases')
ax.set_title('Covid cumalative')
ax.legend(loc='best') # 10 different options available
plt.savefig('covid data.png', dpi = 300)

# %% [markdown]
# #### how to call the different properties in theses two methods
# ```python
# plt.xlabel() → ax.set_xlabel()
# plt.ylabel() → ax.set_ylabel()
# plt.xlim() → ax.set_xlim()
# plt.ylim() → ax.set_ylim()
# plt.title() → ax.set_title()
# ```

# %% [markdown]
# ## sub plots

# %% [markdown]
# Matplotlib’s pyplot API has a convenience function called subplots() which acts as a utility wrapper and helps in creating common layouts of subplots, including the enclosing figure object, in a single call.
#
#  - specifying rows and columns
#  - accessign a specific axes and plot
#  - sharing axis across rows and columns
#  - figure layout options
#  - grid layout to place subplots within a figure

# %%
import matplotlib.pyplot as plt
fig, a =  plt.subplots(2,2, sharex = 'col')#, sharey = 'row')
# or can specify arrays as well

import numpy as np

x = slcd['time line']
y = [ 'total_cases','new_cases','total_deaths', 'new_deaths']
a[0][0].plot(x, slcd[y[0]])
a[0][0].set_title(y[0])
a[0][1].plot(x,slcd[y[1]])
a[0][1].set_title(y[1])
a[1][0].plot(x,slcd[y[2]])
a[1][0].set_title(y[2])
a[1][1].plot(x,slcd[y[3]])
a[1][1].set_title(y[3])

fig.tight_layout(pad = 1)

plt.show()

# %%
fig,a =  plt.subplots(2,2)

# %%
((g,b),(c,d)) = a

# %% [markdown]
# ####  Matplotlib Grid specifcation
#
#  - Advance modifcations to structure multiple axes in different designes inside the figure.
#
#  [Matplotlib official tutorials and application examples on gridspec constructor](https://matplotlib.org/stable/api/_as_gen/matplotlib.gridspec.GridSpec.html#matplotlib.gridspec.GridSpec)

# %% [markdown]
# ## Insets

# %% [markdown]
#  - one of the useful things this allows you to do is include "inset" figures which are often used to show greater detail of a region of the enclosing plot
#
#  - allows easily placing insets in the corners of the axes by specifying a width and height and optionally a location (loc) that accepts locations as codes, similar to legend.
#
#  - specified interms of actual sizes or relative size as percentages of parent figure size.

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=[3*2, 3])

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=[5.5, 2.8])

axins = inset_axes(ax, width=1.3, height=0.9) # at the default upper right location

axins2 = inset_axes(ax, width="30%", height="40%", loc=4) 
# loc 1 = upper right
#loc 2 =  upper left
#loc 3 =  lower left
# loc4 = lower right

axins3 = inset_axes(ax2, width="30%", height=1., loc=2, borderpad=1)

# Create an inset in the lower right corner (loc=4) with borderpad=1, i.e.
# 10 points padding (as 10pt is the default fontsize) to the parent axes
axins4 = inset_axes(ax2, width="20%", height="20%", loc=4, borderpad=1)

# Turn ticklabels of insets off
#for axi in [axins, axins2, axins3, axins4]:
    #axi.tick_params(labelleft=False, labelbottom=False)

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=[10.5, 5.8])

axins = inset_axes(ax, width=1.3, height=0.9) # at the default upper right location

axins2 = inset_axes(ax, width="30%", height="40%", loc=4) 
# loc 1 = upper left
#loc 2 =  upper right
#loc 3 =  lower left
# loc4 = lower right

axins3 = inset_axes(ax2, width="30%", height=1., loc=2)

# Create an inset in the lower right corner (loc=4) with borderpad=1, i.e.
# 10 points padding (as 10pt is the default fontsize) to the parent axes
axins4 = inset_axes(ax2, width="20%", height="20%", loc=4, borderpad=2)

# Turn ticklabels of insets off
for axi in [axins, axins2, axins3]:
    axi.tick_params(labelleft=False, labelbottom=False)

# %% [markdown]
# ### exercize 1

# %% [markdown]
# ## scatter plots

# %% [markdown]
# - scatter plots are useful to compare 2 continous variable. Mostly used to find a relationship between 2 variables.
# - it hepls to find the corealtion between 2 varibles thorugh visual understanding

# %%
x = np.linspace(0, 10, 30)
y = x**2

plt.plot(x, y, '-', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 2);

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, '-v');

# %%
plt.plot(x, y, '-v', color='green',
         markersize=10, linewidth=3,
         markerfacecolor='red',
         markeredgecolor='blue',
         markeredgewidth=1)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ### using plt scatter methode instead of plot

# %% [markdown]
# - main advantage of scattar method over plot is properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.

# %%
plt.scatter(x, y);

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
obj1 = rng.rand(100)
obj2 = 1000 * rng.rand(100)

plt.scatter(x, y, c=obj1, s=obj2, alpha=0.7, #obacity
            cmap='Blues')
plt.colorbar();  # show color scale

# %% [markdown]
# ## Line charts

# %%
x = np.array([1, 2, 3, 4])
y = x*2
plt.plot(x, y)


a = x*2
b = x**2
# first plot with X and Y data
plt.plot(a, b, '-.')

# %%
x = np.linspace(0, 10, 1000)

# specification of color
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1   >> 0 for black
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
## line styles

plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--', color = 'cyan') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %%
## python axis limits

plt.plot(x, x**2)

# %%
## reversing axes limits
plt.plot(x, x**2)

plt.xlim(10, 0)
plt.ylim(100, 0);

# %%
# using python axis to specify x and y limits
plt.plot(x, x**2)
plt.axis([3, 9, 15, 85])
#plt.axis('equal') #ensuring an equal aspect ratio so that on your screen, one unit in x is equal to one unit in y
#plt.axis('tight') #automatically tighten the bounds around the current plot
# Out:
# (3.0, 9.0, 15.0, 85.0)

# %%
slcd['date'] = pd.to_datetime(slcd['date'])
plt.plot(slcd['date'], slcd['total_cases'])
plt.xticks(rotation = 45) ;

# %%
slcd.plot.line(x='date', y = 'new_cases');

# %%
slcd.plot.line(x='date', y = 'new_cases')
slcd.plot.line(x='date', y = ['new_cases','total_cases'])
slcd.plot.line(x='date', y = ['new_cases','total_cases'], subplots = True)
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
slcd['new_cases'].plot()
plt.ylabel('New cases')
slcd['total_cases'].plot(secondary_y=True)
plt.ylabel('Total Cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %% [markdown]
# ## adding legends

# %% [markdown]
# ### legend properties
#
# - location
# - frameon
# - ncol
# - if frame on then >> shadow , framealpha
# - lot of other functions
#
# [visit matplotlib legend advance functions](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html)

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.plot(x, np.sin(x-2), '-.r', label='sin(x-2)')


plt.legend(loc='lower center', frameon= True, ncol = 3,  borderpad=1, framealpha=0.1,  shadow=True)
plt.ylim(-1.4,1)
# Out:
# (-1.4, 1.0)

# %%
# Create the second legend and add the artist manually.
from matplotlib.legend import Legend
fig, ax = plt.subplots()
line_axes = []
line_axes += ax.plot(x, np.sin(x), '-g', label='sin(x)')
line_axes += ax.plot(x, np.cos(x), ':b', label='cos(x)')
line_axes += ax.plot(x, np.sin(x-2), '-.r', label='sin(x)')
line_axes += ax.plot(x, np.cos(x-2), 'y', label='cos(x)')
ax.legend(line_axes[:2],['line A', 'line B'], loc=2)

leg = Legend(ax, line_axes[2:], ['line C', 'line D'],
             loc='lower right', frameon=False)
ax.add_artist(leg);

# %%
line_axes

# %% [markdown]
# ## color maps

# %% [markdown]
#  - colormaps are needed  to differ and make some intuitions in 3D or 2D  parameters. Scientifically, the human brain perceives various intuition based on the different colors they see.
#  - Matplotlib provides some nice colormaps you can use, such as Sequential colormaps, Diverging colormaps, Cyclic colormaps, and Qualitative colormaps.
# [For more information on colormaps !!](https://matplotlib.org/3.3.1/tutorials/colors/colormaps.html)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()
cmaps['Perceptually Uniform Sequential'] = [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']

cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
cmaps['Sequential (2)'] = [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']
cmaps['Diverging'] = [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']
cmaps['Cyclic'] = ['twilight', 'twilight_shifted', 'hsv']


cmaps['Qualitative'] = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']
cmaps['Miscellaneous'] = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral',
            'gist_ncar']
nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps.items())
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps.items():
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %%
x = np.linspace(1,10,100)
y = x*2
y1 = x+1
plt.scatter(x,y)
plt.plot(x,y1)

# %% [markdown]
# ## activity 2
